# %% [markdown]
# ### Практическая работа №2 – Классификация и регрессия

# %% [markdown]
# 1. Загрузите два датасета, один из которых вы будете использовать для классификации данных, другой – для регрессионного анализ.
# 2. Проведите анализ данных используя Jupyter Notebook применяя методы, используемые на занятиях.
# 3. Итоговый файл отправьте на электронную почту `artem@golubnichij.ru` с темой письма **Big Data 09_25**
